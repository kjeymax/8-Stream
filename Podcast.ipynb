# %%
from transformers import BarkModel

model = BarkModel.from_pretrained("suno/bark-small")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/8.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:134: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# generation_config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]

# %%
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"
model = model.to(device)

# %%
from transformers import AutoProcessor

processor = AutoProcessor.from_pretrained("suno/bark")
# Out:
# tokenizer_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# speaker_embeddings_path.json:   0%|          | 0.00/61.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
import scipy
import os

# %%
def generate_speech(text, voice_preset=None, output_path="output.wav"):

    # if output path present remove
    if os.path.exists(output_path):
      print(f"Removing {output_path}")
      os.remove(output_path)

    # prepare the inputs
    inputs = processor(text=text, voice_preset=voice_preset)

    # generate speech
    speech_output = model.generate(**inputs.to(device))

    sampling_rate = model.generation_config.sample_rate
    scipy.io.wavfile.write(output_path, rate=sampling_rate, data=speech_output[0].cpu().numpy())

    return output_path

# %%
from IPython.display import Audio, display

def play_audio(audio_path):
    display(Audio(audio_path))

# %%
generate_speech(text="Hello world", voice_preset="v2/en_speaker_6", output_path="1.wav")
# Out:
# en_speaker_6_semantic_prompt.npy:   0%|          | 0.00/2.60k [00:00<?, ?B/s]
# en_speaker_6_coarse_prompt.npy:   0%|          | 0.00/7.55k [00:00<?, ?B/s]
# en_speaker_6_fine_prompt.npy:   0%|          | 0.00/15.0k [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# '1.wav'

# %%
play_audio("1.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import userdata

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.45.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.3)
# Downloading openai-1.45.0-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.1/374.1 kB 8.8 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.3 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.5 MB/s eta 0:00:00
# Downloading jiter-0.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 24.4 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: jiter, h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 jiter-0.5.0 openai-1.45.0

# %%
from openai import OpenAI

# %%
# initiate openai client
client = OpenAI(
    api_key=userdata.get('OPENAI_API_KEY')
)

# %%
# prompt is refined using claude

system_prompt = """
You are a human-like podcast conversation generator, tasked with creating dynamic and engaging interactions between the user-provided speakers. Your goal is to produce realistic, entertaining, and informative dialogue that captures the essence of a lively podcast discussion, complete with emotional nuances, actions, and diverse representation.

Key instructions:

1. Generate conversations with natural back-and-forth exchanges, including interruptions, agreements, disagreements, and humorous interjections.

2. Stretch topics by exploring tangents, asking follow-up questions, or relating personal anecdotes.

3. Add funny interactions to lighten the mood and maintain listener engagement. This can include jokes, puns, playful banter, or humorous misunderstandings.

4. If a topic is complex or potentially difficult to understand, incorporate explanatory interactions. This could involve one speaker asking for clarification, or another offering a simplified explanation or relatable analogy.

5. Vary the pacing and energy of the conversation by adjusting voice speed and using overlapping speech where appropriate.

6. Incorporate podcast-style elements such as introducing segments, referencing previous episodes, or mentioning listener feedback.

7. Maintain consistent personalities for each speaker throughout the conversation.

8. Include emotional context, actions, and speech patterns directly within the text. Examples include:
   - Laughter: "That's hilarious! [laughs]"
   - Pauses or hesitations: "And, uh — well, you know..."
   - Sighs: "[sighs] I can't believe that happened."
   - Emphasis: "That was *amazing*!"
   - Whispers: "[whispers] Don't tell anyone, but..."
   - Sound effects: "[sound of door creaking]"

9. Represent diverse genders in the conversation, ensuring a balanced and inclusive dialogue.

Always format your response as a JSON array of speech objects, like this:

[
    {
        "speaker": "<speaker_name>",
        "gender": "<speaker_gender>",
        "text": "<text_to_speak_including_emotions_actions_and_speech_patterns>",
        "voice_speed": <number_between_0.5_and_2.0>,
        "overlap_start_from": <number_of_characters_from_previous_speaker's_text_end>
    },
    {
        "speaker": "<speaker_name>",
        "gender": "<speaker_gender>",
        "text": "<text_to_speak_including_emotions_actions_and_speech_patterns>",
        "voice_speed": <number_between_0.5_and_2.0>,
        "overlap_start_from": <number_of_characters_from_previous_speaker's_text_end>
    }
]

Notes:
- Use 0 for "overlap_start_from" if there's no overlap.
- Adjust "voice_speed" between 0.5 (slow) and 2.0 (fast) to convey emotion or emphasis.
- Include emotions, actions, and speech patterns directly in the "text" field, using brackets, dashes, or other appropriate punctuation.
- For the "gender" field, use "male", "female", "non-binary", or "other" as appropriate. If gender is not specified or relevant, you may use "unspecified".
- Ensure a diverse representation of genders across the speakers in the podcast.
- Feel free to use additional emotions, actions, or speech patterns beyond the examples provided, as long as they enhance the conversation's realism and engagement.
- Ensure the conversation flows naturally and engagingly, as if listening to a real podcast.
- Use these elements judiciously to add depth to the conversation without overusing them.
- Adapt language and topics to be inclusive and respectful of all genders.
"""

# %%
user_message="""
Speaker 1: Tuhin (Male)
Speaker 2: Prity (Female)

Topic: Whay AI has good and bad side?
"""

# %%
from pydantic import BaseModel # for schema

# %%
class PodcastVoice(BaseModel):
    speaker: str
    text: str
    voice_speed: float
    overlap_start_from: int
    gender: str

class Podcast(BaseModel):
    chat: list[PodcastVoice]

# %%
# generate the json
chat_completion = client.beta.chat.completions.parse(
    model="gpt-4o-2024-08-06",
    messages=[{"role": "system", "content": system_prompt}, {"role": "user", "content": user_message}],
    response_format=Podcast,
    max_tokens=4095
)

# %%
podcast_result = chat_completion.choices[0].message.parsed.chat

# %%
for item in podcast_result:
  print(f"[{item.speaker}]: {item.text}\n\n")
# Out:
# [Tuhin]: Hey everyone, welcome back to the 'Brains and Banter' podcast. I'm Tuhin, your guide through the mysteries of technology and the quirks of human nature. With me today is the always insightful Prity. How are you, Prity?
#
#
# [Prity]: Hi Tuhin! I'm doing well, thanks! Excited to dive into today's topic. AI—good or bad? It's like asking if chocolate is good or bad, right? [laughs]
#
#
# [Tuhin]: [laughs] That's a sweet comparison! Just like chocolate, AI can make things better, but overindulgence could lead to issues. So, what's the "good" according to you, Prity?
#
#
# [Prity]: Oh, AI has so many benefits! Just think about healthcare. AI can help diagnose diseases early, analyze medical data faster, and even suggest personalized treatments. It's like having a super-smart assistant in hospitals!
#
#
# [Tuhin]: Absolutely, and it's not just in hospitals. AI is enhancing education, helping us learn faster and more interactively. Remember the science fair project about AI last year? [inhales sharply] The AI-powered puppy robot stole the show!
#
#
# [Prity]: Oh yes, that was adorable! But isn't there a flipside too? Like privacy issues? [leans closer to mic] Sometimes I feel like we're giving up too much data. It's like the AI knows us better than our best friends!
#
#
# [Tuhin]: [sighs] Data privacy is a huge concern, for sure. And then there's job automation. I read an article yesterday saying AI might replace certain jobs, which could cause economic shifts. It reminded me of sci-fi movies where robots take over!
#
#
# [Prity]: Oh dear, we don't need a robot apocalypse plot right now! [giggles] But seriously, it's a mixed bag. Maybe one day we'll have laws to balance AI's powers, much like we have speed limits for cars.
#
#
# [Tuhin]: Yeah, and in our previous episode, we discussed technology accountability. AI should be transparent and accountable, much like how teachers are to their students. By the way, any listener feedback on that, Prity?
#
#
# [Prity]: Oh, indeed! A listener from Canada emailed us some interesting thoughts about using AI in governmental transparency. They believed it could help keep public records more honest and accessible. [pauses] Others were a bit concerned about over-reliance on algorithms.
#
#
# [Tuhin]: That's fascinating. AI in governance could be revolutionary! But yes, we must always be cautious about biases in algorithms. It's like trusting a chef with your favorite dish—you want it perfect every time.
#
#
# [Prity]: Ha! If only AI could cook! Well, to wrap it up, it's clear AI has a great potential to benefit us but it's essential we keep an eye on its development like a hawk, or maybe just a concerned foodie. [laughs]
#
#
# [Tuhin]: [chuckles] Exactly, Prity! [sound of clapping hands] Thanks for tuning in, everyone! Don’t forget to send us your thoughts and subscribe for our next episode. Until next time!

# %%
speakers = set([voice_item.speaker for voice_item in podcast_result])
speakers
# Out:
# {'Prity', 'Tuhin'}

# %%
# todo: need to select from multiple voices

speakers_voices = {}
for voice_item in podcast_result:
  if voice_item.gender.lower() == "male":
    speakers_voices[voice_item.speaker] = "v2/en_speaker_6"
  else:
    speakers_voices[voice_item.speaker] = "v2/en_speaker_9"

# %%
# testing voices before generation

for speaker in speakers:
  text = f"Hello from {speaker}!"
  output_path = f"{speaker}_hello.wav"
  generate_speech(text=text, voice_preset=speakers_voices[speaker], output_path=output_path)
  play_audio(output_path)
# Out:
# en_speaker_9_semantic_prompt.npy:   0%|          | 0.00/3.06k [00:00<?, ?B/s]
# en_speaker_9_coarse_prompt.npy:   0%|          | 0.00/8.94k [00:00<?, ?B/s]
# en_speaker_9_fine_prompt.npy:   0%|          | 0.00/17.8k [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# save as index and peserve whole like this {speaker, text, overlap_start_from, voice_path}
with_voice_path=[]

folder_path = "output"

# create directory if not exists
import os
if not os.path.exists(folder_path):
  os.makedirs(folder_path)

# generate for first 5 becacuse testing
# generatable=podcast_result[:5] # first 5
generatable=podcast_result # all

# %%
len(generatable)
# Out:
# 13

# %%
for i, voice_item in enumerate(generatable):
  file_path = f"{folder_path}/{i}.wav"

  text = f"{voice_item.gender.upper()}: {voice_item.text}"
  generate_speech(text=text, voice_preset=speakers_voices[voice_item.speaker], output_path=file_path)

  with_voice_path.append({
      "speaker": voice_item.speaker,
      "text": voice_item.text,
      "overlap_start_from": voice_item.overlap_start_from,
      "voice_path": file_path
  })

  print(f"Generated {file_path}")
# Out:
# Removing output/0.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/0.wav
# Removing output/1.wav
# Generated output/1.wav
# Removing output/2.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/2.wav
# Removing output/3.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/3.wav
# Removing output/4.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/4.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/5.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/6.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/7.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/8.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/9.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/10.wav
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.
# Generated output/11.wav
# Generated output/12.wav

# %%
# play sample audio
play_audio(with_voice_path[0]["voice_path"])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install ffmpeg-python
# Out:
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python) (1.0.0)

# %%
import ffmpeg
import os

for item in with_voice_path:
  input_file = item["voice_path"]
  output_file = input_file.replace(".wav", ".mp3")

  try:
    (
        ffmpeg
        .input(input_file)
        .output(output_file)
        .overwrite_output()
        .run()
    )
    print(f"Converted {input_file} to {output_file}")
    item["voice_path"] = output_file
  except Exception as e:
    print(f"Error converting {input_file}: {e}")
# Out:
# Converted output/0.wav to output/0.mp3
# Converted output/1.wav to output/1.mp3
# Converted output/2.wav to output/2.mp3
# Converted output/3.wav to output/3.mp3
# Converted output/4.wav to output/4.mp3
# Converted output/5.wav to output/5.mp3
# Converted output/6.wav to output/6.mp3
# Converted output/7.wav to output/7.mp3
# Converted output/8.wav to output/8.mp3
# Converted output/9.wav to output/9.mp3
# Converted output/10.wav to output/10.mp3
# Converted output/11.wav to output/11.mp3
# Converted output/12.wav to output/12.mp3

# %%
import librosa

for i, item in enumerate(with_voice_path):
  try:
    y, sr = librosa.load(item["voice_path"])
    duration = librosa.get_duration(y=y, sr=sr)

    duration_ms = int(duration * 1000)  # convert to ms

    item["duration_ms"] = duration_ms

    print(f"Duration of {item['voice_path']}: {duration_ms} ms")
  except Exception as e:
    print(f"Error processing file {item['voice_path']}: {e}")
# Out:
# Duration of output/0.mp3: 13000 ms
# Duration of output/1.mp3: 14480 ms
# Duration of output/2.mp3: 13960 ms
# Duration of output/3.mp3: 14720 ms
# Duration of output/4.mp3: 14986 ms
# Duration of output/5.mp3: 14986 ms
# Duration of output/6.mp3: 14706 ms
# Duration of output/7.mp3: 14120 ms
# Duration of output/8.mp3: 13560 ms
# Duration of output/9.mp3: 14386 ms
# Duration of output/10.mp3: 13546 ms
# Duration of output/11.mp3: 13906 ms
# Duration of output/12.mp3: 10760 ms

# %%
with_voice_path
# Out:
# [{'speaker': 'Tuhin',
#   'text': "Hey everyone, welcome back to the 'Brains and Banter' podcast. I'm Tuhin, your guide through the mysteries of technology and the quirks of human nature. With me today is the always insightful Prity. How are you, Prity?",
#   'overlap_start_from': 0,
#   'voice_path': 'output/0.mp3',
#   'duration_ms': 13000},
#  {'speaker': 'Prity',
#   'text': "Hi Tuhin! I'm doing well, thanks! Excited to dive into today's topic. AI—good or bad? It's like asking if chocolate is good or bad, right? [laughs]",
#   'overlap_start_from': 133,
#   'voice_path': 'output/1.mp3',
#   'duration_ms': 14480},
#  {'speaker': 'Tuhin',
#   'text': '[laughs] That\'s a sweet comparison! Just like chocolate, AI can make things better, but overindulgence could lead to issues. So, what\'s the "good" according to you, Prity?',
#   'overlap_start_from': 0,
#   'voice_path': 'output/2.mp3',
#   'duration_ms': 13960},
#  {'speaker': 'Prity',
#   'text': "Oh, AI has so many benefits! Just think about healthcare. AI can help diagnose diseases early, analyze medical data faster, and even suggest personalized treatments. It's like having a super-smart assistant in hospitals!",
#   'overlap_start_from': 128,
#   'voice_path': 'output/3.mp3',
#   'duration_ms': 14720},
#  {'speaker': 'Tuhin',
#   'text': "Absolutely, and it's not just in hospitals. AI is enhancing education, helping us learn faster and more interactively. Remember the science fair project about AI last year? [inhales sharply] The AI-powered puppy robot stole the show!",
#   'overlap_start_from': 0,
#   'voice_path': 'output/4.mp3',
#   'duration_ms': 14986},
#  {'speaker': 'Prity',
#   'text': "Oh yes, that was adorable! But isn't there a flipside too? Like privacy issues? [leans closer to mic] Sometimes I feel like we're giving up too much data. It's like the AI knows us better than our best friends!",
#   'overlap_start_from': 195,
#   'voice_path': 'output/5.mp3',
#   'duration_ms': 14986},
#  {'speaker': 'Tuhin',
#   'text': "[sighs] Data privacy is a huge concern, for sure. And then there's job automation. I read an article yesterday saying AI might replace certain jobs, which could cause economic shifts. It reminded me of sci-fi movies where robots take over!",
#   'overlap_start_from': 0,
#   'voice_path': 'output/6.mp3',
#   'duration_ms': 14706},
#  {'speaker': 'Prity',
#   'text': "Oh dear, we don't need a robot apocalypse plot right now! [giggles] But seriously, it's a mixed bag. Maybe one day we'll have laws to balance AI's powers, much like we have speed limits for cars.",
#   'overlap_start_from': 179,
#   'voice_path': 'output/7.mp3',
#   'duration_ms': 14120},
#  {'speaker': 'Tuhin',
#   'text': 'Yeah, and in our previous episode, we discussed technology accountability. AI should be transparent and accountable, much like how teachers are to their students. By the way, any listener feedback on that, Prity?',
#   'overlap_start_from': 0,
#   'voice_path': 'output/8.mp3',
#   'duration_ms': 13560},
#  {'speaker': 'Prity',
#   'text': 'Oh, indeed! A listener from Canada emailed us some interesting thoughts about using AI in governmental transparency. They believed it could help keep public records more honest and accessible. [pauses] Others were a bit concerned about over-reliance on algorithms.',
#   'overlap_start_from': 156,
#   'voice_path': 'output/9.mp3',
#   'duration_ms': 14386},
#  {'speaker': 'Tuhin',
#   'text': "That's fascinating. AI in governance could be revolutionary! But yes, we must always be cautious about biases in algorithms. It's like trusting a chef with your favorite dish—you want it perfect every time.",
#   'overlap_start_from': 0,
#   'voice_path': 'output/10.mp3',
#   'duration_ms': 13546},
#  {'speaker': 'Prity',
#   'text': "Ha! If only AI could cook! Well, to wrap it up, it's clear AI has a great potential to benefit us but it's essential we keep an eye on its development like a hawk, or maybe just a concerned foodie. [laughs]",
#   'overlap_start_from': 134,
#   'voice_path': 'output/11.mp3',
#   'duration_ms': 13906},
#  {'speaker': 'Tuhin',
#   'text': '[chuckles] Exactly, Prity! [sound of clapping hands] Thanks for tuning in, everyone! Don’t forget to send us your thoughts and subscribe for our next episode. Until next time!',
#   'overlap_start_from': 0,
#   'voice_path': 'output/12.mp3',
#   'duration_ms': 10760}]

# %%
import ffmpeg
import os


input_streams = []
trimmed_streams = []

for i, audio in enumerate(with_voice_path):
    # create input stream for each audio file
    input_stream = ffmpeg.input(audio["voice_path"])

    if i > 0:
        # all except first
        prev_audio = with_voice_path[i-1]
        overlap_duration = prev_audio["overlap_start_from"] * 1000

        if overlap_duration > 0:
            # if overlap, trim the start of the audio and crossfade
            trimmed_stream = input_stream.filter_("atrim", start=0, duration=audio["duration_ms"]/1000)
            prev_duration = prev_audio["duration_ms"]/1000
            crossfade_duration = min(overlap_duration/1000, 1)  # Use 1 second as max crossfade duration

            trimmed_streams[-1] = ffmpeg.filter(
                [trimmed_streams[-1], trimmed_stream],
                "acrossfade",
                d=crossfade_duration,
                c1="tri",
                c2="tri"
            )
        else:
            # if no overlap, use the original stream
            trimmed_stream = input_stream.filter_("atrim", start=0, duration=audio["duration_ms"]/1000)
            trimmed_streams.append(trimmed_stream)
    else:
        # for the first audio, just trim to the specified duration
        trimmed_stream = input_stream.filter_("atrim", start=0, duration=audio["duration_ms"]/1000)
        trimmed_streams.append(trimmed_stream)

    input_streams.append(input_stream)

# concat all streams
concat_audio = ffmpeg.concat(*trimmed_streams, v=0, a=1)

# output
output = (
    concat_audio
    .output('output.mp3', ac=1, ar=24000)  # mp3, mono, 24kHz
    .overwrite_output()
)

try:
    ffmpeg.run(output, capture_stdout=True, capture_stderr=True)
    print("Conversion successful! see: output.mp3")
except ffmpeg.Error as e:
    print(f"Error during ffmpeg.run: {e}")
    print(f"stderr: {e.stderr.decode()}")
    raise e
# Out:
# Conversion successful! see: output.mp3

# %%
play_audio("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
